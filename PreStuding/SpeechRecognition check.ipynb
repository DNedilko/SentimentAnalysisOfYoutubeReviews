# %% [markdown]
# ###### Downloading libs

# %%
# !pip install SpeechRecognition
# !pip install ffmpeg
# !pip install spaCy
# !pip install SentimentAnalysis
# !pip install pytube   
# !pip install youtube_dl
# !pip install pydub
# !pip install selenium
# !pip install nltk
# !pip install deepmultilingualpunctuation
# !pip install transformers[sentencepiece] datasets
# Out:
# Requirement already satisfied: SpeechRecognition in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (3.9.0)
# Requirement already satisfied: requests>=2.26.0 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from SpeechRecognition) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (3.4)
# Requirement already satisfied: ffmpeg in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (1.4)
# Requirement already satisfied: spaCy in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (3.4.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from spaCy) (0.10.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from spaCy) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from spaCy) (2.4.5)
# Requirement already satisfied: setuptools in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from spaCy) (60.2.0)
# Requirement already satisfied: jinja2 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from spaCy) (3.1.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from spaCy) (1.10.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from spaCy) (2.28.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from spaCy) (1.23.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from spaCy) (1.0.9)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from spaCy) (0.7.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from spaCy) (8.1.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from spaCy) (22.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from spaCy) (4.64.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from spaCy) (3.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from spaCy) (2.0.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from spaCy) (2.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from spaCy) (3.0.10)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from spaCy) (1.0.4)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from spaCy) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from pathy>=0.3.5->spaCy) (6.2.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spaCy) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spaCy) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spaCy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spaCy) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spaCy) (2.1.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from thinc<8.2.0,>=8.1.0->spaCy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from thinc<8.2.0,>=8.1.0->spaCy) (0.0.3)
# Requirement already satisfied: colorama in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spaCy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from typer<0.8.0,>=0.3.0->spaCy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from jinja2->spaCy) (2.1.1)
# Requirement already satisfied: SentimentAnalysis in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (0.8)
# Requirement already satisfied: urllib3 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from SentimentAnalysis) (1.26.13)
# Requirement already satisfied: vaderSentiment in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from SentimentAnalysis) (3.3.2)
# Requirement already satisfied: nltk in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from SentimentAnalysis) (3.7)
# Requirement already satisfied: requests in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from SentimentAnalysis) (2.28.1)
# Requirement already satisfied: tqdm in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from nltk->SentimentAnalysis) (4.64.1)
# Requirement already satisfied: joblib in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from nltk->SentimentAnalysis) (1.2.0)
# Requirement already satisfied: click in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from nltk->SentimentAnalysis) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from nltk->SentimentAnalysis) (2022.10.31)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from requests->SentimentAnalysis) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from requests->SentimentAnalysis) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from requests->SentimentAnalysis) (2.1.1)
# Requirement already satisfied: colorama in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from click->nltk->SentimentAnalysis) (0.4.6)
# Requirement already satisfied: pytube in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (12.1.0)
# Requirement already satisfied: youtube_dl in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (2021.12.17)
# Requirement already satisfied: pydub in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (0.25.1)
# Requirement already satisfied: selenium in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (4.7.2)
# Requirement already satisfied: trio~=0.17 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from selenium) (1.26.13)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: sniffio in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: outcome in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: async-generator>=1.9 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: nltk in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (3.7)
# Requirement already satisfied: joblib in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from nltk) (2022.10.31)
# Requirement already satisfied: click in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from nltk) (8.1.3)
# Requirement already satisfied: tqdm in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: colorama in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: deepmultilingualpunctuation in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (1.0.1)
# Requirement already satisfied: torch>=1.8.1 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from deepmultilingualpunctuation) (1.13.1)
# Requirement already satisfied: transformers in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from deepmultilingualpunctuation) (4.25.1)
# Requirement already satisfied: typing-extensions in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from torch>=1.8.1->deepmultilingualpunctuation) (4.4.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from transformers->deepmultilingualpunctuation) (1.23.5)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from transformers->deepmultilingualpunctuation) (0.11.1)
# Requirement already satisfied: requests in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from transformers->deepmultilingualpunctuation) (2.28.1)
# Requirement already satisfied: filelock in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from transformers->deepmultilingualpunctuation) (3.8.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from transformers->deepmultilingualpunctuation) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from transformers->deepmultilingualpunctuation) (0.13.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from transformers->deepmultilingualpunctuation) (22.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from transformers->deepmultilingualpunctuation) (2022.10.31)
# Requirement already satisfied: tqdm>=4.27 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from transformers->deepmultilingualpunctuation) (4.64.1)
# Requirement already satisfied: colorama in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from tqdm>=4.27->transformers->deepmultilingualpunctuation) (0.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from requests->transformers->deepmultilingualpunctuation) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from requests->transformers->deepmultilingualpunctuation) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from requests->transformers->deepmultilingualpunctuation) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from requests->transformers->deepmultilingualpunctuation) (2.1.1)
# Requirement already satisfied: transformers[sentencepiece] in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (4.25.1)
# Requirement already satisfied: datasets in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (2.8.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from transformers[sentencepiece]) (0.11.1)
# Requirement already satisfied: filelock in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from transformers[sentencepiece]) (3.8.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from transformers[sentencepiece]) (6.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from transformers[sentencepiece]) (1.23.5)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from transformers[sentencepiece]) (2022.10.31)
# Requirement already satisfied: packaging>=20.0 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from transformers[sentencepiece]) (22.0)
# Requirement already satisfied: requests in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from transformers[sentencepiece]) (2.28.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from transformers[sentencepiece]) (4.64.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from transformers[sentencepiece]) (0.13.2)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from transformers[sentencepiece]) (0.1.97)
# Requirement already satisfied: protobuf<=3.20.2 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from transformers[sentencepiece]) (3.20.2)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from datasets) (2022.11.0)
# Requirement already satisfied: pandas in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from datasets) (1.5.2)
# Requirement already satisfied: pyarrow>=6.0.0 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from datasets) (10.0.1)
# Requirement already satisfied: multiprocess in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from datasets) (0.70.14)
# Requirement already satisfied: aiohttp in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from datasets) (3.8.3)
# Requirement already satisfied: xxhash in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from datasets) (3.1.0)
# Requirement already satisfied: dill<0.3.7 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from datasets) (0.3.6)
# Requirement already satisfied: responses<0.19 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from datasets) (0.18.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from huggingface-hub<1.0,>=0.10.0->transformers[sentencepiece]) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from requests->transformers[sentencepiece]) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from requests->transformers[sentencepiece]) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from requests->transformers[sentencepiece]) (3.4)
# Requirement already satisfied: colorama in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from tqdm>=4.27->transformers[sentencepiece]) (0.4.6)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from pandas->datasets) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\dnedi\pycharmprojects\sentimentanalysisofyoutubereviews\venv\lib\site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)

# %% [markdown]
# We`ll be working on analyzing IPhone 14 reviews. [Playlist](!https://youtube.com/playlist?list=PLa-rIqkPf3pFZitDmzHA_VCZTwuc0yEIQ) on YouTube prepared in advance with the latest videos.

# %%
url_playlist = 'https://www.youtube.com/playlist?list=PLa-rIqkPf3pFZitDmzHA_VCZTwuc0yEIQ'
destination = './reviews'

import youtube_dl
import os
import ffmpeg

# %%
'''
driver = webdriver.Chrome()
driver.get(url_playlist)
videos=driver.find_element(By.CLASS_NAME,'style-scope ytd-playlist-video-renderer')
playlist = []

for video in videos:
    link=video.find_element_by_xpath('.//*[@id="content"]/a').get_attribute("href")
    end=link.find("&")
    link=link[:end]
    playlist.append(link)

print(playlist)
'''
playlist = ['https://youtu.be/DbmzO0K4NtQ','https://youtu.be/VwcOYOujmiY','https://youtu.be/XrY9hXaMpug','https://youtu.be/_PLQV6zmcjE']

# %%
# WORKING LOADER
ydl_opts = {'outtmpl': f'{destination}/%(title)s.%(ext)s'}
with youtube_dl.YoutubeDL(ydl_opts) as ydl:
     # ydl.download([playlist[0]])
# Out:
# [youtube] DbmzO0K4NtQ: Downloading webpage
# WARNING: Requested formats are incompatible for merge and will be merged into mkv.
# [download] Resuming download at byte 718362909
# [download] Destination: reviews\iPhone 14 Pro Max One Month Later Review - Do I Regret It.f313.webm
# [download] 100% of 1020.56MiB in 00:16
# [download] Destination: reviews\iPhone 14 Pro Max One Month Later Review - Do I Regret It.f140.m4a
# [download] 100% of 19.01MiB in 00:00
# [ffmpeg] Merging formats into "reviews\iPhone 14 Pro Max One Month Later Review - Do I Regret It.mkv"
# Deleting original file reviews\iPhone 14 Pro Max One Month Later Review - Do I Regret It.f313.webm (pass -k to keep)
# Deleting original file reviews\iPhone 14 Pro Max One Month Later Review - Do I Regret It.f140.m4a (pass -k to keep)

# %%
# Renaming files for convenience

filenames = next(os.walk(destination), (None, None, []))[2]
print(f"Old file names {filenames}")
for num, name in enumerate(filenames):
    n = name.split(".")[0]
    ext = name.split(".")[-1]
    os.rename(destination+"/" +name , destination+"/"+str(num+1) + "." + ext)
# Out:
# Old file names ['1.mkv', '2.mkv']

# %%
apcol = 'C:/Users/dnedi/PycharmProjects/SentimentAnalysisOfYoutubeReviews/pre studing/podcasts/1.mp4'

new_filenames = next(os.walk(destination), (None, None, []))[2]
for name in new_filenames:
    n = name.split(".")[0]
    command = f'ffmpeg -i {destination}/{name} -acodec pcm_s16le -ar 16000 -ac 1 ./wav_data_reviews/{n}.wav'
    os.system(command)

#'iPhone 14 Pro Max One Month Later Review - Do I Regret It'

# %%
wav_filenames_ = next(os.walk("."), (None, None, []))[2]
wav_filenames = next(os.walk("./wav_data_reviews"), (None, None, []))[2]
print(f'New filenames {wav_filenames}')
# Out:
# New filenames ['0_1.wav', '1.wav', '10_1.wav', '12_1.wav', '14_1.wav', '16_1.wav', '18_1.wav', '2.wav', '20_1.wav', '2_1.wav', '4_1.wav', '6_1.wav', '8_1.wav']

# %%
# import SR library
import speech_recognition as sr
from AudioSplit import SplitWavAudioMubin
from pydub import AudioSegment

def match_target_amplitude(sound, target_dBFS):
    change_in_dBFS = target_dBFS - sound.dBFS
    return sound.apply_gain(change_in_dBFS)

# crate an instance of recogniser
recognizer = sr.Recognizer()
# energy threshold - vals below are sounds, above - speech
recognizer.energy_threshold=300
# spaCy for extracting named entities and fillers also can be used for breaking on sentences
folder = "./wav_data_reviews"
file = ["1.wav","2.wav"]

split_wav = SplitWavAudioMubin(folder,file[0])
split_wav.multiple_split(min_per_split=3)
# clean_uk_speech = sr.AudioFile("./wav_data_reviews/2.wav")
file_list = next(os.walk("./wav_data_reviews"), (None, None, []))[2]
print(file_list)
full_eng_text = []
for f in file_list:
    if f == "1.wav" or f == "2.wav": continue

    sound = AudioSegment.from_file(f'{folder}/{f}', "wav")
    normalized_sound = match_target_amplitude(sound, -20.0)
    normalized_sound.export(f'./wav_normalized/norm_{f}', format="wav")
    clean_eng_speech = sr.AudioFile(f'./wav_normalized/norm_{f}')

    with clean_eng_speech as data:
        eng_audio = recognizer.record(data)
    eng_text = recognizer.recognize_google(audio_data=eng_audio,language="en-US",show_all=False)
    print(f'file {f} recognized')
    full_eng_text.append(eng_text)

# with clean_uk_speech as data:
#     uk_audio = recognizer.record(data)



# uk_text = recognizer.recognize_google(audio_data=uk_audio,language="uk",show_all=False)

full_text = " ".join(full_eng_text)
# Out:
# 0 Done
# 3 Done
# 6 Done
# 9 Done
# 12 Done
# 15 Done
# 18 Done
# All splited successfully
# ['0_1.wav', '1.wav', '12_1.wav', '15_1.wav', '18_1.wav', '2.wav', '3_1.wav', '6_1.wav', '9_1.wav']
# result2:
# {   'alternative': [   {   'confidence': 0.95146209,
#                            'transcript': "so I've been using the iPhone 14 Pro "
#                                          'Max for over a month now and if you '
#                                          'remember initially when I bought '
#                                          'this phone I had a lot of concerns '
#                                          'about getting the bigger pro Max '
#                                          'model so for this video I want to '
#                                          'talk about my month over month now '
#                                          "I'm using a 14 Pro Max and how "
#                                          'important are the new features like '
#                                          'the new dynamic Ireland and the '
#                                          'Always on display and is this camera '
#                                          'system really that big of an upgrade '
#                                          'and also stay tuned and make sure '
#                                          'you watch every part of this video '
#                                          'because I bought an extra iPhone 14 '
#                                          'Pro that I want to give away to one '
#                                          'of the people watching this video we '
#                                          'could be you now I have more rolls '
#                                          'later in the video but the easiest '
#                                          'way to enter us to just leave a '
#                                          'comment down below and tell me what '
#                                          'you want and iPhone 14 Pro and I '
#                                          "like the hashtag Greg's gadgets give "
#                                          'away just to make it easier but '
#                                          'before you do all that you might '
#                                          'have noticed that when you purchased '
#                                          'your iPhone 14 Pro there was '
#                                          'something missing yes Apple phones '
#                                          'no longer come with a charging break '
#                                          'included and why you could go buy '
#                                          'some cheap single port charger let '
#                                          'me show you a better alternative '
#                                          "this is your Green's new 141 "
#                                          "charging break yes you didn't hear "
#                                          'me this charging right here has 141 '
#                                          "Max capacity and if you're wondering "
#                                          'how they fit all that what agent to '
#                                          'this relatively medium-sized power '
#                                          "well it's because of ugreen gan "
#                                          'technology and while some Power '
#                                          'brick just give you one poor '
#                                          'connection you greens 140 watt '
#                                          'charger give you access to to high '
#                                          'speed USB c charging ports and 1 USB '
#                                          'a port for maximum compatibility is '
#                                          '140 watt charger even features the '
#                                          'new cutting-edge PD 3.1 protocol to '
#                                          'charge your products even faster '
#                                          'charge a full-size 16-inch MacBook '
#                                          'Pro 256 percent capacity in just 30 '
#                                          'min minutes and it has enough '
#                                          'wattage to charge to 13-inch laptop '
#                                          'at the same time with two spare for '
#                                          'your iPhone that means I can take '
#                                          'everything in my travel bag with my '
#                                          'fortune is my book Pro my Apple '
#                                          'watch ultra and of course my iPhone '
#                                          '14 Pro Max and charge every single '
#                                          'device at fast charging speeds so '
#                                          'make sure you check out the link in '
#                                          'the description to get 25% off your '
#                                          'own you green NEXO charger and thank '
#                                          'you for your green not only for '
#                                          'keeping my tax charged but for also '
#                                          'sponsoring this video is very '
#                                          'similar to the iPhone 13 pro Max and '
#                                          "always it's just a bigger iPhone 13 "
#                                          'pro Max with a bigger camera bump '
#                                          'and the removal of the notch in '
#                                          'exchange for this new pill shaped '
#                                          'cut-out or as apple office to it the '
#                                          'dynamic dynamic Ireland is really '
#                                          'cool first of all I love all the '
#                                          'slick and playful animations that '
#                                          'Apple has incorporated into this '
#                                          'design every time that I swipe up '
#                                          'and see the music player going to '
#                                          'the dynamic Ireland or use Face ID '
#                                          'or getting over like the'},
#                        {   'transcript': "so I've been using the iPhone 14 Pro "
#                                          'Max for over a month now and if you '
#                                          'remember initially when I bought '
#                                          'this phone I had a lot of concerns '
#                                          'about getting the bigger pro Max '
#                                          'model so for this video I want to '
#                                          'talk about my month over month now '
#                                          "I'm using a 14 Pro Max and how "
#                                          'important are the new features like '
#                                          'the new dynamic Ireland and the '
#                                          'Always on display and is this camera '
#                                          'system really that big of an upgrade '
#                                          'and also stay tuned and make sure '
#                                          'you watch every part of this video '
#                                          'because I bought an extra iPhone 14 '
#                                          'Pro that I want to give away to one '
#                                          'of the people watching this video we '
#                                          'could be you now I have more rolls '
#                                          'later in the video but the easiest '
#                                          'way to enter us to just leave a '
#                                          'comment down below and tell me what '
#                                          'you want and iPhone 14 Pro and I '
#                                          "like the hashtag Greg's gadgets give "
#                                          'away just to make it easier but '
#                                          'before you do all that you might '
#                                          'have noticed that when you purchased '
#                                          'your iPhone 14 Pro there was '
#                                          'something missing yes Apple phones '
#                                          'no longer come with a charging break '
#                                          'included and why you could go buy '
#                                          'some cheap single port charger let '
#                                          'me show you a better alternative '
#                                          "this is your Green's new 141 "
#                                          "charging break yes you didn't hear "
#                                          'me this charging right here has 141 '
#                                          "Max capacity and if you're wondering "
#                                          'how they fit all that what agent to '
#                                          'this relatively medium-sized power '
#                                          "well it's because of ugreen gan "
#                                          'technology and while some Power '
#                                          'brick just give you one poor '
#                                          'connection you greens 140 watt '
#                                          'charger give you access to to high '
#                                          'speed USB c charging ports and 1 USB '
#                                          'a port for maximum compatibility is '
#                                          '140 watt charger even features the '
#                                          'new cutting-edge PD 3.1 protocol to '
#                                          'charge your products even faster '
#                                          'charge a full-size 16-inch MacBook '
#                                          'Pro 256 percent capacity in just 30 '
#                                          'min minutes and it has enough '
#                                          'wattage to charge to 13-inch laptop '
#                                          'at the same time with two spare for '
#                                          'your iPhone that means I can take '
#                                          'everything in my travel bag with my '
#                                          'fortune is my book Pro my Apple '
#                                          'watch ultra and of course my iPhone '
#                                          '14 Pro Max and charge every single '
#                                          'device at fast charging speeds so '
#                                          'make sure you check out the link in '
#                                          'the description to get 25% off your '
#                                          'own you green NEXO charger and thank '
#                                          'you for your green not only for '
#                                          'keeping my tax charged but for also '
#                                          'sponsoring this video is very '
#                                          'similar to the iPhone 13 pro Max and '
#                                          "always it's just a bigger iPhone 13 "
#                                          'pro Max with a bigger camera bump '
#                                          'and the removal of the notch in '
#                                          'exchange for this new pill shaped '
#                                          'cut-out or as apple office to it the '
#                                          'dynamic dynamic Ireland is really '
#                                          'cool first of all I love all the '
#                                          'slick and playful animations that '
#                                          'Apple has incorporated into the '
#                                          'design every time that I swipe up '
#                                          'and see the music player going to '
#                                          'the dynamic Ireland or use Face ID '
#                                          'or getting over like the'},
#                        {   'transcript': "so I've been using the iPhone 14 Pro "
#                                          'Max for over a month now and if you '
#                                          'remember initially when I bought '
#                                          'this phone I had a lot of concerns '
#                                          'about getting the bigger pro Max '
#                                          'model so for this video I want to '
#                                          'talk about my month over month now '
#                                          "I'm using a 14 Pro Max and how "
#                                          'important are the new features like '
#                                          'the new dynamic Ireland and the '
#                                          'Always on display and is this camera '
#                                          'system really that big of an upgrade '
#                                          'and also stay tuned and make sure '
#                                          'you watch every part of this video '
#                                          'because I bought an extra iPhone 14 '
#                                          'Pro that I want to give away to one '
#                                          'of the people watching this video we '
#                                          'could be you now I have more rolls '
#                                          'later in the video but the easiest '
#                                          'way to enter us to just leave a '
#                                          'comment down below and tell me why '
#                                          'you want an iPhone 14 Pro and I like '
#                                          "the hashtag Greg's gadgets give away "
#                                          'just to make it easier but before '
#                                          'you do all that you might have '
#                                          'noticed that when you purchased your '
#                                          'iPhone 14 Pro there was something '
#                                          'missing yes Apple phones no longer '
#                                          'come with a charging break included '
#                                          'and why you could go buy some cheap '
#                                          'single port charger let me show you '
#                                          'a better alternative this is your '
#                                          "Green's new 141 charging break yes "
#                                          "you didn't hear me this charging "
#                                          'right here has 141 Max capacity and '
#                                          "if you're wondering how they fit all "
#                                          'that what agent to this relatively '
#                                          "medium-sized power well it's because "
#                                          'of ugreen gan technology and while '
#                                          'some Power brick just give you one '
#                                          'poor connection you greens 140 watt '
#                                          'charger give you access to to high '
#                                          'speed USB c charging ports and 1 USB '
#                                          'a port for maximum compatibility is '
#                                          '140 watt charger even features the '
#                                          'new cutting-edge PD 3.1 protocol to '
#                                          'charge your products even faster '
#                                          'charge a full-size 16-inch MacBook '
#                                          'Pro 256 percent capacity in just 30 '
#                                          'min minutes and it has enough '
#                                          'wattage to charge to 13-inch laptop '
#                                          'at the same time with two spare for '
#                                          'your iPhone that means I can take '
#                                          'everything in my travel bag with my '
#                                          'fortune is my book Pro my Apple '
#                                          'watch ultra and of course my iPhone '
#                                          '14 Pro Max and charge every single '
#                                          'device at fast charging speeds so '
#                                          'make sure you check out the link in '
#                                          'the description to get 25% off your '
#                                          'own you green NEXO charger and thank '
#                                          'you for your green not only for '
#                                          'keeping my tax charged but for also '
#                                          'sponsoring this video is very '
#                                          'similar to the iPhone 13 pro Max and '
#                                          "always it's just a bigger iPhone 13 "
#                                          'pro Max with a bigger camera bump '
#                                          'and the removal of the notch in '
#                                          'exchange for this new pill shaped '
#                                          'cut-out or as apple office to it the '
#                                          'dynamic dynamic Ireland is really '
#                                          'cool first of all I love all the '
#                                          'slick and playful animations that '
#                                          'Apple has incorporated into this '
#                                          'design every time that I swipe up '
#                                          'and see the music player going to '
#                                          'the dynamic Ireland or use Face ID '
#                                          'or getting over like the'},
#                        {   'transcript': "I've been using the iPhone 14 Pro "
#                                          'Max for over a month now and if you '
#                                          'remember initially when I bought '
#                                          'this phone I had a lot of concerns '
#                                          'about getting the bigger pro Max '
#                                          'model so for this video I want to '
#                                          'talk about my month over month now '
#                                          "I'm using a 14 Pro Max and how "
#                                          'important are the new features like '
#                                          'the new dynamic Ireland and the '
#                                          'Always on display and is this camera '
#                                          'system really that big of an upgrade '
#                                          'and also stay tuned and make sure '
#                                          'you watch every part of this video '
#                                          'because I bought an extra iPhone 14 '
#                                          'Pro that I want to give away to one '
#                                          'of the people watching this video we '
#                                          'could be you now I have more rolls '
#                                          'later in the video but the easiest '
#                                          'way to enter us to just leave a '
#                                          'comment down below and tell me what '
#                                          'you want and iPhone 14 Pro and I '
#                                          "like the hashtag Greg's gadgets give "
#                                          'away just to make it easier but '
#                                          'before you all that you might have '
#                                          'noticed that when you purchased your '
#                                          'iPhone 14 Pro there was something '
#                                          'missing yes Apple phones no longer '
#                                          'come with a charging break included '
#                                          'and why you could go buy some cheap '
#                                          'single port charger let me show you '
#                                          'a better alternative this is your '
#                                          "Green's new 141 charging break yes "
#                                          "you didn't hear me this charging "
#                                          'right here has 141 Max capacity and '
#                                          "if you're wondering how they fit all "
#                                          'that what agent to this relatively '
#                                          "medium-sized power well it's because "
#                                          'of ugreen gan technology and while '
#                                          'some Power brick just give you one '
#                                          'poor connection you greens 140 watt '
#                                          'charger give you access to to high '
#                                          'speed USB c charging ports and 1 USB '
#                                          'a port for maximum compatibility is '
#                                          '140 watt charger even features the '
#                                          'new cutting-edge PD 3.1 protocol to '
#                                          'charge your products even faster '
#                                          'charge a full-size 16-inch MacBook '
#                                          'Pro 256 percent capacity in just 30 '
#                                          'min minutes and it has enough '
#                                          'wattage to charge to 13-inch laptop '
#                                          'at the same time with two spare for '
#                                          'your iPhone that means I can take '
#                                          'everything in my travel bag with my '
#                                          'fortune is my book Pro my Apple '
#                                          'watch ultra and of course my iPhone '
#                                          '14 Pro Max and charge every single '
#                                          'device at fast charging speeds so '
#                                          'make sure you check out the link in '
#                                          'the description to get 25% off your '
#                                          'own you green NEXO charger and thank '
#                                          'you for your green not only for '
#                                          'keeping my tax charged but for also '
#                                          'sponsoring this video is very '
#                                          'similar to the iPhone 13 pro Max and '
#                                          "always it's just a bigger iPhone 13 "
#                                          'pro Max with a bigger camera bump '
#                                          'and the removal of the notch in '
#                                          'exchange for this new pill shaped '
#                                          'cut-out or as apple office to it the '
#                                          'dynamic dynamic Ireland is really '
#                                          'cool first of all I love all the '
#                                          'slick and playful animations that '
#                                          'Apple has incorporated into this '
#                                          'design every time that I swipe up '
#                                          'and see the music player going to '
#                                          'the dynamic Ireland or use Face ID '
#                                          'or getting over like the'},
#                        {   'transcript': "so I've been using the iPhone 14 Pro "
#                                          'Max for over a month now and if you '
#                                          'remember initially when I bought '
#                                          'this phone I had a lot of concerns '
#                                          'about getting the bigger pro Max '
#                                          'model so for this video I want to '
#                                          'talk about my month over month now '
#                                          "I'm using a 14 Pro Max and how "
#                                          'important are the new features like '
#                                          'the new dynamic Ireland and the '
#                                          'Always on display and is this camera '
#                                          'system really that big of an upgrade '
#                                          'and also stay tuned and make sure '
#                                          'you watch every part of this video '
#                                          'because I bought an extra iPhone 14 '
#                                          'Pro that I want to give away to one '
#                                          'of the people watching this video we '
#                                          'could be you now I have more rolls '
#                                          'later in the video but the easiest '
#                                          'way to enter us to just leave a '
#                                          'comment down below and tell me what '
#                                          'you want and iPhone 14 Pro and I '
#                                          "like the hashtag Greg's gadgets give "
#                                          'away just to make it easier but '
#                                          'before you do all that you might '
#                                          'have noticed that when you purchased '
#                                          'your iPhone 14 Pro there was '
#                                          'something missing yes Apple phones '
#                                          'no longer come with a charging break '
#                                          'included and why you could go buy '
#                                          'some cheap single port charger let '
#                                          'me show you a better alternative '
#                                          "this is your Green's new 141 "
#                                          "charging break yes you didn't hear "
#                                          'me this charging right here has 141 '
#                                          "Max capacity and if you're wondering "
#                                          'how they fit all that what agent to '
#                                          'this relatively medium-sized power '
#                                          "well it's because of ugreen gan "
#                                          'technology and while some Power '
#                                          'brick just give you one poor '
#                                          'connection you greens 140 watt '
#                                          'charger give you access to to high '
#                                          'speed USB c charging ports and 1 USB '
#                                          'a port for maximum compatibility is '
#                                          '140 watt charger even features the '
#                                          'new cutting-edge PD 3.1 protocol to '
#                                          'charge your products even faster '
#                                          'charge a full-size 16-inch MacBook '
#                                          'Pro 256 percent capacity in just 30 '
#                                          'min minutes and it has enough '
#                                          'wattage to charge to 13-inch laptop '
#                                          'at the same time with two spare for '
#                                          'your iPhone that means I can take '
#                                          'everything in my travel bag with my '
#                                          'fortune is my book Pro my Apple '
#                                          'watch ultra and of course my iPhone '
#                                          '14 Pro Max and charge every single '
#                                          'device at fast charging speeds so '
#                                          'make sure you check out the link in '
#                                          'the description to get 25% off your '
#                                          'own you green NEXO charger and thank '
#                                          'you for your green not only for '
#                                          'keeping my tax charged but for also '
#                                          'sponsoring this video is very '
#                                          'similar to the iPhone 13 pro Max and '
#                                          "always it's just a bigger iPhone 13 "
#                                          'pro Max with a bigger camera bump '
#                                          'and the removal of the notch in '
#                                          'exchange for this new pill shaped '
#                                          'cut-out or as apple reverse to it '
#                                          'the dynamic dynamic Ireland is '
#                                          'really cool first of all I love all '
#                                          'the slick and playful animations '
#                                          'that Apple has incorporated into the '
#                                          'design every time that I swipe up '
#                                          'and see the music player going to '
#                                          'the dynamic Ireland or use Face ID '
#                                          'or getting over like the'}],
#     'final': True}
# file 0_1.wav recognized
# result2:
# {   'alternative': [   {   'confidence': 0.95007771,
#                            'transcript': 'I can still get a zoom in on a '
#                                          'subject and get very similar quality '
#                                          'to the main One X camera by using '
#                                          "this to explore because it's using "
#                                          'the main camera sensor other cameras '
#                                          'are still there the ultra wide is '
#                                          'still the best option if you need to '
#                                          'capture every subject in the frame '
#                                          'and can possibly back up anymore and '
#                                          "it's still has that useful macro "
#                                          'mode where you can get really close '
#                                          'up two subjects and take a close-up '
#                                          'photo with lots of detail camera is '
#                                          'there to providing just a bit more '
#                                          'zoom for far away subjects that is '
#                                          'just redundant most of the time I '
#                                          "don't want to use it because it "
#                                          'results in a poor quality photos and '
#                                          'the new 2x camera and I think of '
#                                          'Apple wants to keep a third zoom '
#                                          'lens on here they should increase '
#                                          'the magnification to at least a580 '
#                                          "doesn't have too much is here has "
#                                          'its own separate system is very '
#                                          'baffling but I guess apples just '
#                                          'waiting for another iPhone year to '
#                                          'update that she went at least I hope '
#                                          'so perhaps one of my favourite '
#                                          'camera upgrades actually has nothing '
#                                          'to do with this rear camera system '
#                                          "it's on the front facing camera "
#                                          'which Apple has updated to now '
#                                          'include autofocus and gave it just a '
#                                          'better or sensor the results from '
#                                          'this are just crazy going like the '
#                                          'front facing camera is probably '
#                                          'better than older rear camera '
#                                          'systems that the iPhone used to have '
#                                          "and honestly it's not the pictures I "
#                                          "like the most famous upgrade it's "
#                                          'the video party that you get out of '
#                                          'the front facing camera really '
#                                          'shines to me like the best way that '
#                                          'I can describe the benefits of this '
#                                          'upgrades for the front facing camera '
#                                          'is before I would just know how '
#                                          'inferior the front facing camera was '
#                                          'compared to the rear camera so if I '
#                                          'wanted to like record like a selfie '
#                                          'video I just rotate the camera so '
#                                          'that the rear camera was like this '
#                                          'right so I can do this and I take a '
#                                          'video that I can see myself which is '
#                                          "kind of annoying when you're trying "
#                                          'to blame yourself in a video well '
#                                          "now I don't feel the need to do that "
#                                          "anymore I'm going to take a selfie "
#                                          'selfie video I just use the front '
#                                          'camera because the quality is that '
#                                          "good I don't feel like I'm losing "
#                                          'out that much and feel poorly '
#                                          'compared to the rear camera in fact '
#                                          'video All Around is just really '
#                                          'great looking only 13 pro cinematic '
#                                          'mode is also great now I can do 24 '
#                                          'frames per second at 4 k and I can '
#                                          'look really convincing sometimes I '
#                                          'create a nice or official blur '
#                                          'reaction is just fun for outdoor use '
#                                          'provided you have enough to '
#                                          'demonstrate the capabilities of the '
#                                          '14 pros use Canesten actually shot '
#                                          'an entire video on it when using the '
#                                          'iPhone 14 plus which you can find '
#                                          'right here address and personal '
#                                          'things that I purposely stayed for '
#                                          'the end of the video and Factor and '
#                                          'M battery life so when I first '
#                                          'bought this phone I was really '
#                                          'worried about the size and weight '
#                                          'and this is the biggest and heaviest '
#                                          'phone that Apple has ever sold and '
#                                          'you can definitely feel that and '
#                                          'while I was really worried about '
#                                          'using such a big phone after being '
#                                          'on the 12 Mini and then the 13 pro I '
#                                          'have to say that the experience '
#                                          "hasn't been terrible like my father "
#                                          'most annoying thing with this size '
#                                          'and weight I just putting in my '
#                                          'pocket like it feels like a break in '
#                                          'my pocket'},
#                        {   'transcript': 'I can still get a zoom in on a '
#                                          'subject and get very similar quality '
#                                          'to the main One X camera by using '
#                                          "this to explore because it's using "
#                                          'the main camera sensor other cameras '
#                                          'are still there the ultrawide is '
#                                          'still the best option if you need to '
#                                          'capture every subject in the frame '
#                                          'and can possibly back up anymore and '
#                                          "it's still has that useful macro "
#                                          'mode where you can get really close '
#                                          'up two subjects and take a close-up '
#                                          'photo with lots of detail camera is '
#                                          'there to providing just a bit more '
#                                          'zoom for far away subjects that is '
#                                          'just redundant most of the time I '
#                                          "don't want to use it because it "
#                                          'results in a poor quality photos and '
#                                          'the new 2x camera and I think of '
#                                          'Apple wants to keep a third zoom '
#                                          'lens on here they should increase '
#                                          'the magnification to at least a580 '
#                                          "doesn't have too much is here has "
#                                          'its own separate system is very '
#                                          'baffling but I guess apples just '
#                                          'waiting for another iPhone year to '
#                                          'update that she went at least I hope '
#                                          'so perhaps one of my favourite '
#                                          'camera upgrades actually has nothing '
#                                          'to do with this rear camera system '
#                                          "it's on the front facing camera "
#                                          'which Apple has updated to now '
#                                          'include autofocus and gave it just a '
#                                          'better or sensor the results from '
#                                          'this are just crazy going like the '
#                                          'front facing camera is probably '
#                                          'better than older rear camera '
#                                          'systems that the iPhone used to have '
#                                          "and honestly it's not the pictures I "
#                                          "like the most famous upgrade it's "
#                                          'the video party that you get out of '
#                                          'the front facing camera really '
#                                          'shines to me like the best way that '
#                                          'I can describe the benefits of this '
#                                          'upgrades for the front facing camera '
#                                          'is before I would just know how '
#                                          'inferior the front facing camera was '
#                                          'compared to the rear camera so if I '
#                                          'wanted to like record like a selfie '
#                                          'video I just rotate the camera so '
#                                          'that the rear camera was like this '
#                                          'right so I can do this and I take a '
#                                          'video that I can see myself which is '
#                                          "kind of annoying when you're trying "
#                                          'to blame yourself in a video well '
#                                          "now I don't feel the need to do that "
#                                          "anymore I'm going to take a selfie "
#                                          'selfie video I just use the front '
#                                          'camera because the quality is that '
#                                          "good I don't feel like I'm losing "
#                                          'out that much and feel poorly '
#                                          'compared to the rear camera in fact '
#                                          'video All Around is just really '
#                                          'great looking only 13 pro cinematic '
#                                          'mode is also great now I can do 24 '
#                                          'frames per second at 4 k and I can '
#                                          'look really convincing sometimes I '
#                                          'create a nice or official blur '
#                                          'reaction is just fun for outdoor use '
#                                          'provided you have enough to '
#                                          'demonstrate the capabilities of the '
#                                          '14 pros use Canesten actually shot '
#                                          'an entire video on it when using the '
#                                          'iPhone 14 plus which you can find '
#                                          'right here address and personal '
#                                          'things that I purposely stayed for '
#                                          'the end of the video and Factor and '
#                                          'M battery life so when I first '
#                                          'bought this phone I was really '
#                                          'worried about the size and weight '
#                                          'and this is the biggest and heaviest '
#                                          'phone that Apple has ever sold and '
#                                          'you can definitely feel that and '
#                                          'while I was really worried about '
#                                          'using such a big phone after being '
#                                          'on the 12 Mini and then the 13 pro I '
#                                          'have to say that the experience '
#                                          "hasn't been terrible like my father "
#                                          'most annoying thing with this size '
#                                          'and weight I just putting in my '
#                                          'pocket like it feels like a break in '
#                                          'my pocket'},
#                        {   'transcript': 'I can still get a zoom in on a '
#                                          'subject and get very similar quality '
#                                          'to the main One X camera by using '
#                                          "this to explore because it's using "
#                                          'the main camera sensor other cameras '
#                                          'are still there the ultra wide is '
#                                          'still the best option if you need to '
#                                          'capture every subject in the frame '
#                                          'and can possibly back up anymore and '
#                                          "it's still has that useful macro "
#                                          'mode where you can get really close '
#                                          'up two subjects and take a close-up '
#                                          'photo with lots of detail camera is '
#                                          'there to providing just a bit more '
#                                          'zoom for far away subjects that is '
#                                          'just redundant most of the time I '
#                                          "don't want to use it because it "
#                                          'results in a poor quality photos and '
#                                          'the new 2x camera and I think of '
#                                          'Apple wants to keep a third zoom '
#                                          'lens on here they should increase '
#                                          'the magnification to at least a580 '
#                                          "doesn't have too much is here has "
#                                          'its own separate system is very '
#                                          'baffling but I guess apples just '
#                                          'waiting for another iPhone year to '
#                                          'update that she went at least I hope '
#                                          'so perhaps one of my favourite '
#                                          'camera upgrades actually has nothing '
#                                          'to do with this rear camera system '
# ...
#                                          "like it's probably not a feature "
#                                          "that you're going to appreciate but "
#                                          'from a or 4 people who do editor '
#                                          'photos this increased flexibility is '
#                                          'another tool in the tool belt when '
#                                          'it comes to deciding how you want to '
#                                          'take photos and it makes this camera '
#                                          'system for me much more versatile '
#                                          'now apple also utilises this bigger '
#                                          '48 megapixel sensor to introduce a '
#                                          "new 2x camera mode we're basically "
#                                          'digitally crops into the sensor to '
#                                          'zoom and but still give you a full '
#                                          '12 megapixel photo at twice focal '
#                                          'length this is one of my new '
#                                          'favourite features on the iPhone 14 '
#                                          'plus camera system because honestly '
#                                          'I will always default using the main '
#                                          'camera system not the wide angle '
#                                          'lens or the zoom lens because the '
#                                          'main camera usually looks so much '
#                                          'better especially in Lower light '
#                                          'situations and because of this'},
#                        {   'transcript': 'shipping 12 megapixel sensors on his '
#                                          "phone's since the iPhone 6s and "
#                                          'still does on the regular iPhone 14 '
#                                          'regular use apple ulises 48 '
#                                          'megapixel sensor and use a process '
#                                          'called pixel Binning which basically '
#                                          'means the camera sensor captures the '
#                                          'day of a 48 megapixel photo and '
#                                          'emergencies pixels together '
#                                          'basically to condense that down and '
#                                          'bring it back down to a 12 megapixel '
#                                          "resolution so it doesn't take up "
#                                          'space on your phone that I might '
#                                          'experience is usually results in '
#                                          'photos with more detail than the '
#                                          'iPhone that just have the 12 '
#                                          'megapixel sensor overall photos look '
#                                          'crisp have a bit more punching the '
#                                          "colours to them and I can't really "
#                                          'take some stunning photos without '
#                                          'loss in speed when pressing the '
#                                          'camera shutter I will say one '
#                                          'critical part I have with the camera '
#                                          'system is some of the word decisions '
#                                          'that makes now to me with this '
#                                          'example I would say that I prefer '
#                                          'the choices the iPhone 14 camera '
#                                          'made the regular iPhone 14 compared '
#                                          'to the iPhone 14 Pro I like the '
#                                          "iPhone 14 photo better and I've also "
#                                          'found some other weirdness with the '
#                                          '14 Pro axis camera system with smart '
#                                          'HDR like with the sample photos I '
#                                          'took the HDR just looks really '
#                                          'unnatural to me but those are just '
#                                          'two small cases out of a bunch of '
#                                          "photos that I took where I wasn't "
#                                          'necessarily pleased with the results '
#                                          'but for the most part I am pleased '
#                                          'with most of the pictures that does '
#                                          '14 Pro Max Camera system takes '
#                                          "what's really quite the camera "
#                                          'system to me as you can utilise the '
#                                          'full 48 megapixel sensor if you '
#                                          'choose to toggle apples prosetting '
#                                          "and it's one of the reasons why I "
#                                          'love this camera so much because '
#                                          'when you do toggle that you get a '
#                                          'picture with much more detail when '
#                                          'you crop in and give you much more '
#                                          'flexibility for blowing up these '
#                                          'pictures if you want to print them '
#                                          "out there's also some negatives with "
#                                          'this feature and the first will be '
#                                          'that it drastically slows down the '
#                                          'camera when using 48 megapixel '
#                                          'sensor and it does take a few '
#                                          'seconds to press the shutter again '
#                                          'and take another picture doll '
#                                          'compared to the regular milk because '
#                                          'they are raw photos meaning that are '
#                                          "really make them shine you're going "
#                                          'to want to edit them and a photo '
#                                          'editing app so I think most normal '
#                                          "users watching this video who don't "
#                                          "edit photos you probably don't need "
#                                          'to use the 48 megapixel raw sensor '
#                                          "like it's probably not a feature "
#                                          "that you're going to appreciate but "
#                                          'from a or for people who do editor '
#                                          'photos this increased flexibility is '
#                                          'another tool in the tool belt when '
#                                          'it comes to deciding how you want to '
#                                          'take photos and it makes this camera '
#                                          'system for me much more versatile '
#                                          'now apple also utilises this bigger '
#                                          '48 megapixel sensor to introduce a '
#                                          'new 2x camera Mode work basically '
#                                          'digitally crops into the sensor to '
#                                          'zoom in but still give you a full 12 '
#                                          'megapixel photo at twice focal '
#                                          'length this is one of my new '
#                                          'favourite features on the iPhone 14 '
#                                          'plus camera system because honestly '
#                                          'I will always default using the main '
#                                          'camera system not the wide angle '
#                                          'lens or the zoom lens because the '
#                                          'main camera usually looks so much '
#                                          'better especially in Lower like '
#                                          'situations and because of this'},
#                        {   'transcript': 'shipping 12 megapixel sensors on '
#                                          "this phone's since the iPhone 6s and "
#                                          'still does on the regular iPhone 14 '
#                                          'regular use apple ulises 48 '
#                                          'megapixel sensor and use a process '
#                                          'called pixel Binning which basically '
#                                          'means the camera sensor captures the '
#                                          'day of a 48 megapixel photo and '
#                                          'emergencies pixels together '
#                                          'basically to condense that down and '
#                                          'bring it back down to a 12 megapixel '
#                                          "resolution so it doesn't take up "
#                                          'space on your phone that I might '
#                                          'experience is usually results in '
#                                          'photos with more detail than the '
#                                          'iPhone that just have the 12 '
#                                          'megapixel sensor overall photos look '
#                                          'crisp have a bit more punch in the '
#                                          "colours to them and I can't really "
#                                          'take some stunning photos without '
#                                          'loss in speed when pressing the '
#                                          'camera shutter I will say one '
#                                          'critical part I have with the camera '
#                                          'system is some of the word decisions '
#                                          'that makes now to me with this '
#                                          'example I would say that I prefer '
#                                          'the choices the iPhone 14 camera '
#                                          'made the regular iPhone 14 compared '
#                                          'to the iPhone 14 Pro I like the '
#                                          "iPhone 14 photo better and I've also "
#                                          'found some other weirdness with the '
#                                          '14 Pro axis camera system with smart '
#                                          'HDR like with the sample photos I '
#                                          'took the HDR just looks really '
#                                          'unnatural to me but those are just '
#                                          'two small cases out of a bunch of '
#                                          "photos that I took where I wasn't "
#                                          'necessarily pleased with the results '
#                                          'but for the most part I am pleased '
#                                          'with most of the pictures that does '
#                                          '14 Pro Max Camera system takes '
#                                          "what's really quite the camera "
#                                          'system to me as you can utilise the '
#                                          'full 48 megapixel sensor if you '
#                                          'choose to toggle apples prosetting '
#                                          "and it's one of the reasons why I "
#                                          'love this camera so much because '
#                                          'when you do toggle that you get a '
#                                          'picture with much more detail when '
#                                          'you crop in and give you much more '
#                                          'flexibility for blowing up these '
#                                          'pictures if you want to print them '
#                                          "out there's also some negatives with "
#                                          'this feature and the first will be '
#                                          'that it drastically slows down the '
#                                          'camera when using 48 megapixel '
#                                          'sensor and it does take a few '
#                                          'seconds to press the shutter again '
#                                          'and take another picture doll '
#                                          'compared to the regular milk because '
#                                          'they are raw photos meaning that are '
#                                          "really make them shine you're going "
#                                          'to want to edit them and a photo '
#                                          'editing app so I think most normal '
#                                          "users watching this video who don't "
#                                          "edit photos you probably don't need "
#                                          'to use the 48 megapixel raw sensor '
#                                          "like it's probably not a feature "
#                                          "that you're going to appreciate but "
#                                          'from a or for people who do editor '
#                                          'photos this increased flexibility is '
#                                          'another tool in the tool belt when '
#                                          'it comes to deciding how you want to '
#                                          'take photos and it makes this camera '
#                                          'system for me much more versatile '
#                                          'now apple also utilises this bigger '
#                                          '48 megapixel sensor to introduce a '
#                                          'new 2x camera Mode work basically '
#                                          'digitally crops into the sensor to '
#                                          'zoom and but still give you a full '
#                                          '12 megapixel photo at twice focal '
#                                          'length this is one of my new '
#                                          'favourite features on the iPhone 14 '
#                                          'plus camera system because honestly '
#                                          'I will always default using the main '
#                                          'camera system not the wide angle '
#                                          'lens or the zoom lens because the '
#                                          'main camera usually looks so much '
#                                          'better especially in Lower light '
#                                          'situations and because of this'}],
#     'final': True}
# file 9_1.wav recognized

# %%
# NLP part of the project
from deepmultilingualpunctuation import PunctuationModel
from nltk import sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer, LancasterStemmer, SnowballStemmer
from nltk.stem import WordNetLemmatizer

def stem(data, stemmer):
    stem_data=[]
    for sent in data:
        stem_temp = []
        for word in sent:
            stem_temp.append(stemmer.stem(word))
        stem_data.append(stem_temp)
    return stem_data

def data_to_tokens(doc):
    punctuations="?:!.,;"
    sentences = sent_tokenize(doc)
    sent_words = []
    for sentence in sentences:
        print(sentence, '\n')
        words = word_tokenize(sentence)
        for word in words:
            if word in punctuations: words.remove(word)
        sent_words.append(words)

    return sent_words


# porter = PorterStemmer(use_fast = False)
wordnet_lemmatizer = WordNetLemmatizer()

snow_stemmer = SnowballStemmer(language='english')
porter = PorterStemmer()
model = PunctuationModel()
result = model.restore_punctuation(full_text)
# lancaster=LancasterStemmer()


sent_words = data_to_tokens(full_text)
print(sent_words)
# stemmed_data = stem(sent_words, snow_stemmer)
#
# print(stemmed_data[1:3])

# %%
import spacy
from spacy import displacy
'''
NER = spacy.load("en_core_web_sm")
text1= NER(full_text)

for word in text1.ents:
    print(word.text,word.label_)
'''
sent_words = data_to_tokens(full_text)

stemmed_data = stem(sent_words, snow_stemmer)
#
print(stemmed_data[1:3])
# Out:
# so I've been using the iPhone 14 Pro Max for over a month now and if you remember initially when I bought this phone I had a lot of concerns about getting the bigger pro Max model so for this video I want to talk about my month over month now I'm using a 14 Pro Max and how important are the new features like the new dynamic Ireland and the Always on display and is this camera system really that big of an upgrade and also stay tuned and make sure you watch every part of this video because I bought an extra iPhone 14 Pro that I want to give away to one of the people watching this video we could probably you now I have more rolls later in the video but the easiest way to enter us to just leave a comment down below and tell me what you want and iPhone 14 Pro and I like the hashtag Greg's gadgets give away just to make it easier but before you do all that you might have noticed that when you purchased your iPhone 14 Pro there was something missing yes Apple phones no longer come with a charging brick included and why you could go buy some cheap single port charger let me show you a better alternative this is your Green's new 141 charging break yes you didn't hear me this charging right here has 141 Max capacity and if you're wondering how they fit all that what agent to this relatively medium-sized power well it's because of ugreen gan technology and while some Power bricks just give you one poor connection you greens 140 watt charger give you access to to high speed USB c charging ports and 1 USB a port for maximum compatibility is 140 watt charger even features the new cutting-edge PD 3.1 protocol to charge your products even faster charge a full-size 16-inch MacBook Pro 256 percent capacity in just 30 camera system with smart HDR like with the sample photos I took the HR just looks really unnatural to me but those are just two small cases out of a bunch of photos that I took where I wasn't necessarily pleased with the results but for the most part I am pleased with most of the pictures that does 14 Pro Max Camera system takes what's really quite the camera system to me as you can utilise the full 48 megapixel sensor if you choose to toggle apples pro setting and it's one of the reasons why I love this camera so much because when you do toggle that you get a picture with much more detail when you drop in and it gives you much more flexibility for blowing up these pictures if you want to print them out there's also some negatives with this feature and the first will be that it drastically slows down the camera when using 48 megapixel sensor and it does take a few seconds to press the shutter again and take another picture compared to the regular mode because they are rough photos meaning at a really make them shine you're going to want to edit them and a photo editing app so I think most normal users watching this video who don't edit photos you probably don't need to use the 48 megapixel raw sensor like it's probably not a feature that you're going to appreciate but for me or for people who do editor photos this increased flexibility is another tool in the tool bell when it comes to deciding how you want to take photos and it makes this camera system for me much more versatile now apple also utilises this bigger 48 megapixel sensor to introduce a new 2x camera mode where basically digitally crops into the sensor to zoom but still give you a full 12 megapixel photo at twice focal length this is one of my new favourite features on the iPhone 14 plus camera system because honestly I will always default using the main camera system not the wide angle lens or the zoom lens because the main camera usually looks so much better especially in Lower light situations and because of this I can still get a zoom in on a subject and get very similar quality to the main One X camera by using this to explore because it's using the main camera sensor other cameras are still there the ultra wide is the best option if you need to capture every subje ...
# []
